# %% [markdown]
# # Classify the CIFAR-10

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Models

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import tqdm as tqdm # fancy progress bars
import matplotlib.pyplot as plt
import torchvision # for loading CIFAR dataset and visualizing images

# %%
import onnx

def save_onnx(model, filename):
    base_path = "projects/blog/3-cifar10/models/"
    dummy_input = torch.randn(1, 3, 32, 32)
    torch.onnx.export(model, dummy_input, base_path + filename, verbose=True, input_names=['images'], output_names=['classes'], export_params=True)

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=torchvision.transforms.ToTensor())
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=torchvision.transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=256, shuffle=True, num_workers=2, persistent_workers=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=256, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def train(
    model,
    train_loader,
    test_loader,
    num_epochs=10,
    lr=0.1,
    momentum=0.9,
    optimizer = "sgd",
):
    # Loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    if optimizer == "sgd":
        optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    elif optimizer == "adam":
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    # Statistics dictionary
    stats = {"train_losses": [0], "test_losses": [0], "global_step": 0}

    # Training loop
    with tqdm.trange(
        num_epochs, desc="Training", unit="epoch"
    ) as epochs:  # Adjust the number of epochs
        for epoch in epochs:
            model.train()
            for images, labels in train_loader:
                images, labels = images.to(device), labels.to(device)

                outputs = model(images)

                loss = criterion(outputs, labels)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                stats["train_losses"].append(loss.item())
                stats["global_step"] += 1

                epochs.set_postfix_str(f"train loss: {stats['train_losses'][-1]:.6f}, test loss: {stats['test_losses'][-1]:.6f}")

            model.eval()
            test_loss = 0
            with torch.no_grad():
                for images, labels in test_loader:
                    images, labels = images.to(device), labels.to(device)

                    outputs = model(images)

                    loss = criterion(outputs, labels)

                    test_loss += loss.item()

            stats["test_losses"].append(test_loss / len(test_loader))

    return stats

def test(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)

            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct / total

def plot_stats(stats):
    # Plot train and test losses
    plt.figure(figsize=(20, 4))
    plt.plot(stats["train_losses"], label="Train Loss")
    plt.plot(
        range(
            len(train_loader),
            len(stats["train_losses"]) + len(train_loader),
            len(train_loader),
        ),
        stats["test_losses"],
        label="Test Loss",
        c="r",
    )
    plt.title("Train and Test Loss")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.yscale("log")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# ### LeNet-5

# %%
torch.manual_seed(0) # for reproducibility if you care about that

# Define the model
model = nn.Sequential(
    nn.Conv2d(3, 6, kernel_size=5),
    nn.Tanh(),
    nn.AvgPool2d(2),
    nn.Conv2d(6, 16, kernel_size=5),
    nn.Tanh(),
    nn.AvgPool2d(2),
    nn.Flatten(),
    nn.Linear(16 * 5 * 5, 120*3),
    nn.Tanh(),
    nn.Linear(120*3, 84*3),
    nn.Tanh(),
    nn.Linear(84*3, 10),
).to(device)

stats = train(model, train_loader, test_loader)

plot_stats(stats)

print(f"Accuracy: {test(model, test_loader):.4f}")
print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"Model size: {sum(p.numel() * p.element_size() for p in model.parameters()):,} bytes")

save_onnx(model, "lenet-5.onnx")
# Out:
# Training:   0%|          | 0/10 [00:00<?, ?epoch/s]
# Training: 100%|██████████| 10/10 [03:00<00:00, 18.03s/epoch, train loss: 1.058127, test loss: 1.290027]
# Accuracy: 0.5376
# Model parameters: 240,734
# Model size: 962,936 bytes
# Exported graph: graph(%images : Float(1, 3, 32, 32, strides=[3072, 1024, 32, 1], requires_grad=0, device=cpu),
#       %0.weight : Float(6, 3, 5, 5, strides=[75, 25, 5, 1], requires_grad=1, device=cpu),
#       %0.bias : Float(6, strides=[1], requires_grad=1, device=cpu),
#       %3.weight : Float(16, 6, 5, 5, strides=[150, 25, 5, 1], requires_grad=1, device=cpu),
#       %3.bias : Float(16, strides=[1], requires_grad=1, device=cpu),
#       %7.weight : Float(360, 400, strides=[400, 1], requires_grad=1, device=cpu),
#       %7.bias : Float(360, strides=[1], requires_grad=1, device=cpu),
#       %9.weight : Float(252, 360, strides=[360, 1], requires_grad=1, device=cpu),
#       %9.bias : Float(252, strides=[1], requires_grad=1, device=cpu),
#       %11.weight : Float(10, 252, strides=[252, 1], requires_grad=1, device=cpu),
#       %11.bias : Float(10, strides=[1], requires_grad=1, device=cpu)):
#   %/0/Conv_output_0 : Float(1, 6, 28, 28, strides=[4704, 784, 28, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/0/Conv"](%images, %0.weight, %0.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.conv.Conv2d::0 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/conv.py:456:0
#   %/1/Tanh_output_0 : Float(1, 6, 28, 28, strides=[4704, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Tanh[onnx_name="/1/Tanh"](%/0/Conv_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.activation.Tanh::1 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/activation.py:356:0
#   %/2/AveragePool_output_0 : Float(1, 6, 14, 14, strides=[1176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::AveragePool[ceil_mode=0, count_include_pad=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/2/AveragePool"](%/1/Tanh_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.pooling.AvgPool2d::2 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/pooling.py:631:0
#   %/3/Conv_output_0 : Float(1, 16, 10, 10, strides=[1600, 100, 10, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/3/Conv"](%/2/AveragePool_output_0, %3.weight, %3.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.conv.Conv2d::3 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/conv.py:456:0
#   %/4/Tanh_output_0 : Float(1, 16, 10, 10, strides=[1600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Tanh[onnx_name="/4/Tanh"](%/3/Conv_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.activation.Tanh::4 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/activation.py:356:0
#   %/5/AveragePool_output_0 : Float(1, 16, 5, 5, strides=[400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::AveragePool[ceil_mode=0, count_include_pad=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/5/AveragePool"](%/4/Tanh_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.pooling.AvgPool2d::5 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/pooling.py:631:0
#   %/6/Flatten_output_0 : Float(1, 400, strides=[400, 1], requires_grad=1, device=cpu) = onnx::Flatten[axis=1, onnx_name="/6/Flatten"](%/5/AveragePool_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.flatten.Flatten::6 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/flatten.py:49:0
#   %/7/Gemm_output_0 : Float(1, 360, strides=[360, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="/7/Gemm"](%/6/Flatten_output_0, %7.weight, %7.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.linear.Linear::7 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/linear.py:116:0
#   %/8/Tanh_output_0 : Float(1, 360, strides=[360, 1], requires_grad=1, device=cpu) = onnx::Tanh[onnx_name="/8/Tanh"](%/7/Gemm_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.activation.Tanh::8 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/activation.py:356:0
#   %/9/Gemm_output_0 : Float(1, 252, strides=[252, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="/9/Gemm"](%/8/Tanh_output_0, %9.weight, %9.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.linear.Linear::9 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/linear.py:116:0
#   %/10/Tanh_output_0 : Float(1, 252, strides=[252, 1], requires_grad=1, device=cpu) = onnx::Tanh[onnx_name="/10/Tanh"](%/9/Gemm_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.activation.Tanh::10 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/activation.py:356:0
#   %classes : Float(1, 10, strides=[10, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="/11/Gemm"](%/10/Tanh_output_0, %11.weight, %11.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.linear.Linear::11 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/linear.py:116:0
#   return (%classes)

# %%
# Recent Model Training Techniques
# Better Optimizers
# Adam
model = nn.Sequential(
    nn.Conv2d(3, 6, kernel_size=5),
    nn.ReLU(),
    nn.AvgPool2d(2),
    nn.Conv2d(6, 16, kernel_size=5),
    nn.ReLU(),
    nn.AvgPool2d(2),
    nn.Flatten(),
    nn.Linear(16 * 5 * 5, 120*3),
    nn.ReLU(),
    nn.Linear(120*3, 84*3),
    nn.ReLU(),
    nn.Linear(84*3, 10),
).to(device)

stats = train(model, train_loader, test_loader, num_epochs=20, lr=1e-3, optimizer="adam")

plot_stats(stats)

print(f"Accuracy: {test(model, test_loader):.4f}")
print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"Model size: {sum(p.numel() * p.element_size() for p in model.parameters()):,} bytes")

save_onnx(model, "lenet-5-adam.onnx")
# Out:
# Training: 100%|██████████| 20/20 [06:06<00:00, 18.32s/epoch, train loss: 0.744128, test loss: 1.108511]
# Accuracy: 0.6137
# Model parameters: 240,734
# Model size: 962,936 bytes
# Exported graph: graph(%images : Float(1, 3, 32, 32, strides=[3072, 1024, 32, 1], requires_grad=0, device=cpu),
#       %0.weight : Float(6, 3, 5, 5, strides=[75, 25, 5, 1], requires_grad=1, device=cpu),
#       %0.bias : Float(6, strides=[1], requires_grad=1, device=cpu),
#       %3.weight : Float(16, 6, 5, 5, strides=[150, 25, 5, 1], requires_grad=1, device=cpu),
#       %3.bias : Float(16, strides=[1], requires_grad=1, device=cpu),
#       %7.weight : Float(360, 400, strides=[400, 1], requires_grad=1, device=cpu),
#       %7.bias : Float(360, strides=[1], requires_grad=1, device=cpu),
#       %9.weight : Float(252, 360, strides=[360, 1], requires_grad=1, device=cpu),
#       %9.bias : Float(252, strides=[1], requires_grad=1, device=cpu),
#       %11.weight : Float(10, 252, strides=[252, 1], requires_grad=1, device=cpu),
#       %11.bias : Float(10, strides=[1], requires_grad=1, device=cpu)):
#   %/0/Conv_output_0 : Float(1, 6, 28, 28, strides=[4704, 784, 28, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/0/Conv"](%images, %0.weight, %0.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.conv.Conv2d::0 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/conv.py:456:0
#   %/1/Relu_output_0 : Float(1, 6, 28, 28, strides=[4704, 784, 28, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/1/Relu"](%/0/Conv_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.activation.ReLU::1 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/functional.py:1473:0
#   %/2/AveragePool_output_0 : Float(1, 6, 14, 14, strides=[1176, 196, 14, 1], requires_grad=1, device=cpu) = onnx::AveragePool[ceil_mode=0, count_include_pad=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/2/AveragePool"](%/1/Relu_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.pooling.AvgPool2d::2 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/pooling.py:631:0
#   %/3/Conv_output_0 : Float(1, 16, 10, 10, strides=[1600, 100, 10, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/3/Conv"](%/2/AveragePool_output_0, %3.weight, %3.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.conv.Conv2d::3 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/conv.py:456:0
#   %/4/Relu_output_0 : Float(1, 16, 10, 10, strides=[1600, 100, 10, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/4/Relu"](%/3/Conv_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.activation.ReLU::4 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/functional.py:1473:0
#   %/5/AveragePool_output_0 : Float(1, 16, 5, 5, strides=[400, 25, 5, 1], requires_grad=1, device=cpu) = onnx::AveragePool[ceil_mode=0, count_include_pad=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2], onnx_name="/5/AveragePool"](%/4/Relu_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.pooling.AvgPool2d::5 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/pooling.py:631:0
#   %/6/Flatten_output_0 : Float(1, 400, strides=[400, 1], requires_grad=1, device=cpu) = onnx::Flatten[axis=1, onnx_name="/6/Flatten"](%/5/AveragePool_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.flatten.Flatten::6 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/flatten.py:49:0
#   %/7/Gemm_output_0 : Float(1, 360, strides=[360, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="/7/Gemm"](%/6/Flatten_output_0, %7.weight, %7.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.linear.Linear::7 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/linear.py:116:0
#   %/8/Relu_output_0 : Float(1, 360, strides=[360, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/8/Relu"](%/7/Gemm_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.activation.ReLU::8 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/functional.py:1473:0
#   %/9/Gemm_output_0 : Float(1, 252, strides=[252, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="/9/Gemm"](%/8/Relu_output_0, %9.weight, %9.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.linear.Linear::9 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/linear.py:116:0
#   %/10/Relu_output_0 : Float(1, 252, strides=[252, 1], requires_grad=1, device=cpu) = onnx::Relu[onnx_name="/10/Relu"](%/9/Gemm_output_0), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.activation.ReLU::10 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/functional.py:1473:0
#   %classes : Float(1, 10, strides=[10, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1, onnx_name="/11/Gemm"](%/10/Relu_output_0, %11.weight, %11.bias), scope: torch.nn.modules.container.Sequential::/torch.nn.modules.linear.Linear::11 # /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/nn/modules/linear.py:116:0
#   return (%classes)

# %% [markdown]
# ### AlexNet

# %% [markdown]
# ### VGG-16

# %%
cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}

class VGG(nn.Module):
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(cfg[vgg_name])
        self.classifier = nn.Linear(512, 10)

    def forward(self, x):
        out = self.features(x)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out

    def _make_layers(self, cfg):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
        layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)
    
model = VGG('VGG16').to(device)

stats = train(model, train_loader, test_loader, num_epochs=20, lr=2e-4, optimizer="adam")

plot_stats(stats)

print(f"Accuracy: {test(model, test_loader):.4f}")
print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"Model size: {sum(p.numel() * p.element_size() for p in model.parameters()):,} bytes")

save_onnx(model, "vgg16.onnx")
# Out:
# Training:  60%|██████    | 12/20 [2:41:09<1:58:12, 886.51s/epoch, train loss: 0.068222, test loss: 0.991209]

# %% [markdown]
# ### ResNet

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])
def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])
def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])
def ResNet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])
def ResNet152():
    return ResNet(Bottleneck, [3, 8, 36, 3])

# %% [markdown]
# #### ResNet-18

# %%
model = ResNet18().to(device)

stats = train(model, train_loader, test_loader)

plot_stats(stats)

print(f"Accuracy: {test(model, test_loader):.4f}")
print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"Model size: {sum(p.numel() * p.element_size() for p in model.parameters()):,} bytes")

save_onnx(model, "resnet18.onnx")

# %% [markdown]
# #### ResNet-34

# %%
model = ResNet34().to(device)

stats = train(model, train_loader, test_loader)

plot_stats(stats)

print(f"Accuracy: {test(model, test_loader):.4f}")
print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"Model size: {sum(p.numel() * p.element_size() for p in model.parameters()):,} bytes")

save_onnx(model, "resnet34.onnx")
